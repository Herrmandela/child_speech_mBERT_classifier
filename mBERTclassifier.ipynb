# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r "/content/drive/MyDrive/gn4n/dependencies.txt"
# !pip install -r "/content/drive/MyDrive/gn4n/augmented_dependencies.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 37.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# !python "/content/drive/MyDrive/gn4n/main.py"
# Out:
# || +++In menus.py +++ Loaded ||
#
#
#
# +++++++In menus.py+++++++
# Loading training data in menus.py
#
#
#
# +++++++In load_paradigm.py+++++++
#
#
#
# ** MENU +++++ in menus.py **
# - Binary (for TOLD only
# - Multiclass (for TOLD/CELF)
# - Augmented (CELF)
# - Exit
#
# Please choose language model: augmented
# Processing...++++++  in menus.py
# You choose the Augmented Paradigm
# 1
# +++++++In load_paradigm.py+++++++
# Loading Augmented Experiment...
#
#
# || +++In augmented_three.py - AUGMENTED Model COMMAND +++ Loaded ||
#
#
#
# GPU Settings2: returns device in GPU_Settings.py
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA A100-SXM4-40GB
#
# imports in augmented_imports.py
#
# 2024-05-09 21:14:16.777427: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %run "/content/drive/MyDrive/gn4n/main.py"
# Out:
# || +++In menus.py +++ Loaded ||
#
#
#
# +++++++In menus.py+++++++
# Loading training data in menus.py
#
#
# ** MENU +++++ in menus.py **
# - Binary (for TOLD only
# - Multiclass (for TOLD/CELF)
# - Augmented (CELF)
# - Exit
#
# Please choose language model: augmented
# Processing...++++++  in menus.py
# You choose the Augmented Paradigm
# 1
# +++++++In load_paradigm.py+++++++
# Loading Augmented Experiment...
#
#
# || +++In augmented_three.py - AUGMENTED Model COMMAND +++ Loaded ||
#
#
#
# GPU Settings2: returns device in GPU_Settings.py
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA A100-SXM4-40GB
#
# ** MENU ++++++ in augmented_three.py **
# - English
# - Farsi
# - Greek
# - Multilingual
# - Exit
#
# Please choose language model: english
# Processing...
# You choose English
#
# 1
# Loading English ++++++ in augmented_load_data.py
# Number of test sentences: 8,100
#
#
# ** MENU ++++++ in augmented_three.py **
# Vanilla - ( * No layers Frozen * )
# ...
